# %%
import pickle

history_path = "result/tcc_II/2/history.pkl"

with open(history_path, "rb") as file:

    loaded_data = pickle.load(file)

    print(loaded_data)
# Out:
# {'loss': [588.3868408203125, 347.1894836425781, 307.214111328125, 305.5935363769531, 295.40972900390625, 297.307373046875, 296.9627685546875, 292.2059020996094, 291.3793029785156, 288.2469177246094, 284.29547119140625, 288.4927062988281, 278.2706298828125, 277.9828186035156, 271.9494934082031, 266.2311096191406, 256.0012512207031, 249.20071411132812, 245.56491088867188, 239.96148681640625, 238.0279083251953, 233.5388946533203, 231.71661376953125, 230.39645385742188, 230.3834686279297, 225.380859375, 226.66331481933594, 221.65382385253906, 217.5456085205078, 220.12539672851562, 215.71847534179688, 211.83572387695312, 211.37159729003906, 208.5203857421875, 206.00204467773438, 202.23373413085938, 203.40968322753906, 200.51983642578125, 199.6516876220703, 199.70877075195312, 198.12449645996094, 195.7279815673828, 194.08509826660156, 194.13241577148438, 191.80345153808594, 190.2354736328125, 188.14584350585938, 187.2765655517578, 185.6064453125, 184.64454650878906, 184.1803436279297, 182.
# ...

# %%
import pandas as pd
import numpy as np

csv_path = "result/statistical_test/tcc_I/errors.csv"

csv = pd.read_csv(csv_path)

print(np.mean(csv["Erro_Bruto"] ** 2))
# Out:
# 104.53187869739087
