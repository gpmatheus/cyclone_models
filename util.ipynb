# %%
import pandas as pd
import matplotlib.pyplot as plt
import h5py

# %%
labelsfile = pd.read_hdf("/Users/matheussonego/Documents/Unipampa/tcc/cyclone_models/data/preprocessed/train.h5", key="info", mode="r")

im = labelsfile[labelsfile["ID"] == "200301L"]
print(im)
# Out:
#      data_set       ID   lon   lat        time  Vmax  R35_4qAVG    MSLP
# 4392     ATLN  200301L -66.0  29.9  2003041806  30.0        0.0  1008.0
# 4393     ATLN  200301L -65.9  30.4  2003041809  30.0        0.0  1008.0
# 4394     ATLN  200301L -65.8  30.8  2003041812  30.0        0.0  1008.0
# 4395     ATLN  200301L -66.0  31.4  2003041815  30.0        0.0  1008.0
# 4396     ATLN  200301L -66.3  31.9  2003041818  30.0        0.0  1007.0
# ...       ...      ...   ...   ...         ...   ...        ...     ...
# 4462     ATLN  200301L -29.2  34.4  2003042700  40.0        0.0  1002.0
# 4463     ATLN  200301L -27.5  34.8  2003042703  40.0        0.0  1001.0
# 4464     ATLN  200301L -25.8  35.3  2003042706  40.0        0.0   999.0
# 4465     ATLN  200301L -24.1  35.7  2003042709  40.0        0.0  1000.0
# 4466     ATLN  200301L -22.4  36.1  2003042712  40.0        0.0  1000.0
#
# [75 rows x 8 columns]

# %%
a = labelsfile.iloc[4392]

a
# Out:
# data_set           ATLN
# ID              200608L
# lon               -55.0
# lat                30.1
# time         2006091421
# Vmax              102.0
# R35_4qAVG         105.0
# MSLP              959.0
# Name: 8784, dtype: object
